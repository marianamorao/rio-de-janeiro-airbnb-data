# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Dataset
#df = pd.read_csv(r'total_data.csv', low_memory=False)
#Use only the Semptember df 
df = pd.read_csv(r'setembro2019.csv', low_memory=False)
df.head
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34329 entries, 0 to 34328
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(24), int64(21), object(61)
# memory usage: 27.8+ MB

# %%
#Transform the price columns to numeric
def convert_currency(column):
    return df[column].replace('[\$,]', '', regex=True).astype(float)

price_columns = ['price', 'security_deposit', 'cleaning_fee', 'extra_people']
for col in price_columns:
    df[col] = convert_currency(col)

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.432900e+04  3.432900e+04  3.432900e+04         34315.000000
# mean   1.744310e+07  2.019092e+13  7.015939e+07             9.302288
# std    1.106711e+07  8.824347e+00  7.122795e+07            39.530907
# min    1.787800e+04  2.019092e+13  2.616000e+03             0.000000
# 25%    9.992237e+06  2.019092e+13  1.426431e+07             1.000000
# 50%    1.413587e+07  2.019092e+13  5.184224e+07             1.000000
# 75%    2.740455e+07  2.019092e+13  8.695143e+07             3.000000
# max    3.884766e+07  2.019092e+13  2.973608e+08           772.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               34315.000000  34329.000000  34329.000000  34329.000000
# mean                    9.302288    -22.965061    -43.254485      4.190014
# std                    39.530907      0.035320      0.097822      2.606760
# min                     0.000000    -23.073400    -43.737090      1.000000
# 25%                     1.000000    -22.984690    -43.324050      2.000000
# 50%                     1.000000    -22.970710    -43.200310      4.000000
# 75%                     3.000000    -22.945390    -43.187070      5.000000
# max                   772.000000    -22.750380    -43.104060    160.000000
#
#           bathrooms      bedrooms  ...  review_scores_cleanliness  \
# count  34272.000000  34300.000000  ...               17316.000000
# mean       1.688448      1.638513  ...                   9.411989
# std        1.483623      1.052694  ...                   1.108830
# min        0.000000      0.000000  ...                   2.000000
# 25%        1.000000      1.000000  ...                   9.000000
# 50%        1.000000      1.000000  ...                  10.000000
# 75%        2.000000      2.000000  ...                  10.000000
# max      200.000000     13.000000  ...                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           17309.000000                 17317.000000
# mean                9.782194                     9.752267
# std                 0.772284                     0.800108
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count            17314.000000         17314.000000
# mean                 9.731951             9.328000
# std                  0.749477             1.018182
# min                  2.000000             2.000000
# 25%                 10.000000             9.000000
# 50%                 10.000000            10.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  \
# count                    34329.000000
# mean                         7.646858
# std                         29.889300
# min                          1.000000
# 25%                          1.000000
# 50%                          1.000000
# 75%                          3.000000
# max                        249.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 34329.000000
# mean                                      6.683271
# std                                      29.395366
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     249.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  34329.000000
# mean                                       0.753911
# std                                        1.959514
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       40.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 34329.000000       18285.000000
# mean                                      0.090011           0.618036
# std                                       0.740312           0.879252
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.100000
# 50%                                       0.000000           0.240000
# 75%                                       0.000000           0.810000
# max                                      18.000000          10.510000
#
# [8 rows x 42 columns]

# %%
#Check null values
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Valores Nulos en el Dataset")
plt.show()

# %%
# Eliminate columns with more 80% null values
df = df.dropna(axis=1, how='all')

# %%
#Fill null values in prices with de average
for col in price_columns:
    df[col].fillna(df[col].median(), inplace=True)

# %%
#Fill in category with the more frecuency value
categorical_columns = ['neighbourhood', 'room_type', 'property_type']
for col in categorical_columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34329 entries, 0 to 34328
# Data columns (total 96 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            34329 non-null  int64
#  1   listing_url                                   34329 non-null  object
#  2   scrape_id                                     34329 non-null  int64
#  3   last_scraped                                  34329 non-null  object
#  4   name                                          34265 non-null  object
#  5   summary                                       32445 non-null  object
#  6   space                                         21117 non-null  object
#  7   description                                   33472 non-null  object
#  8   experiences_offered                           34329 non-null  object
#  9   neighborhood_overview                         18828 non-null  object
#  10  notes                                         11165 non-null  object
#  11  transit                                       18698 non-null  object
#  12  access                                        16481 non-null  object
#  13  interaction                                   16962 non-null  object
#  14  house_rules                                   17696 non-null  object
#  15  picture_url                                   34329 non-null  object
#  16  host_id                                       34329 non-null  int64
#  17  host_url                                      34329 non-null  object
#  18  host_name                                     34315 non-null  object
#  19  host_since                                    34315 non-null  object
#  20  host_location                                 34151 non-null  object
#  21  host_about                                    16608 non-null  object
#  22  host_response_time                            20336 non-null  object
#  23  host_response_rate                            20336 non-null  object
#  24  host_is_superhost                             34315 non-null  object
#  25  host_thumbnail_url                            34315 non-null  object
#  26  host_picture_url                              34315 non-null  object
#  27  host_neighbourhood                            21629 non-null  object
#  28  host_listings_count                           34315 non-null  float64
#  29  host_total_listings_count                     34315 non-null  float64
#  30  host_verifications                            34329 non-null  object
#  31  host_has_profile_pic                          34315 non-null  object
#  32  host_identity_verified                        34315 non-null  object
#  33  street                                        34329 non-null  object
#  34  neighbourhood                                 34329 non-null  object
#  35  neighbourhood_cleansed                        34329 non-null  object
#  36  city                                          34282 non-null  object
#  37  state                                         34279 non-null  object
#  38  zipcode                                       32557 non-null  object
#  39  market                                        34282 non-null  object
#  40  smart_location                                34329 non-null  object
#  41  country_code                                  34329 non-null  object
#  42  country                                       34329 non-null  object
#  43  latitude                                      34329 non-null  float64
#  44  longitude                                     34329 non-null  float64
#  45  is_location_exact                             34329 non-null  object
#  46  property_type                                 34329 non-null  object
#  47  room_type                                     34329 non-null  object
#  48  accommodates                                  34329 non-null  int64
#  49  bathrooms                                     34272 non-null  float64
#  50  bedrooms                                      34300 non-null  float64
#  51  beds                                          34294 non-null  float64
#  52  bed_type                                      34329 non-null  object
#  53  amenities                                     34329 non-null  object
#  54  price                                         34329 non-null  float64
#  55  security_deposit                              34329 non-null  float64
#  56  cleaning_fee                                  34329 non-null  float64
#  57  guests_included                               34329 non-null  int64
#  58  extra_people                                  34329 non-null  float64
#  59  minimum_nights                                34329 non-null  int64
#  60  maximum_nights                                34329 non-null  int64
#  61  minimum_minimum_nights                        34329 non-null  int64
#  62  maximum_minimum_nights                        34329 non-null  int64
#  63  minimum_maximum_nights                        34329 non-null  int64
#  64  maximum_maximum_nights                        34329 non-null  int64
#  65  minimum_nights_avg_ntm                        34329 non-null  float64
#  66  maximum_nights_avg_ntm                        34329 non-null  float64
#  67  calendar_updated                              34329 non-null  object
#  68  has_availability                              34329 non-null  object
#  69  availability_30                               34329 non-null  int64
#  70  availability_60                               34329 non-null  int64
#  71  availability_90                               34329 non-null  int64
#  72  availability_365                              34329 non-null  int64
#  73  calendar_last_scraped                         34329 non-null  object
#  74  number_of_reviews                             34329 non-null  int64
#  75  number_of_reviews_ltm                         34329 non-null  int64
#  76  first_review                                  18285 non-null  object
#  77  last_review                                   18285 non-null  object
#  78  review_scores_rating                          17332 non-null  float64
#  79  review_scores_accuracy                        17312 non-null  float64
#  80  review_scores_cleanliness                     17316 non-null  float64
#  81  review_scores_checkin                         17309 non-null  float64
#  82  review_scores_communication                   17317 non-null  float64
#  83  review_scores_location                        17314 non-null  float64
#  84  review_scores_value                           17314 non-null  float64
#  85  requires_license                              34329 non-null  object
#  86  instant_bookable                              34329 non-null  object
#  87  is_business_travel_ready                      34329 non-null  object
#  88  cancellation_policy                           34329 non-null  object
#  89  require_guest_profile_picture                 34329 non-null  object
#  90  require_guest_phone_verification              34329 non-null  object
#  91  calculated_host_listings_count                34329 non-null  int64
#  92  calculated_host_listings_count_entire_homes   34329 non-null  int64
#  93  calculated_host_listings_count_private_rooms  34329 non-null  int64
#  94  calculated_host_listings_count_shared_rooms   34329 non-null  int64
#  95  reviews_per_month                             18285 non-null  float64
# dtypes: float64(21), int64(21), object(54)
# memory usage: 25.1+ MB

# %% [markdown]
# # Top 10 Most Popular Neighbourhoods

# %%
# Group by neighbourhood and calculate the number of listings, average price, and average review score
neighbourhood_stats = df.groupby('neighbourhood_cleansed').agg(
    number_of_listings=('id', 'count'),
    average_price=('price', 'mean'),
    average_review_score=('review_scores_rating', 'mean')
).reset_index()

# Sort by number of listings to identify the most popular neighbourhood
neighbourhood_stats = neighbourhood_stats.sort_values(by='number_of_listings', ascending=False)

# Display the most popular neighbourhood
most_popular_neighbourhood = neighbourhood_stats.iloc[0]
print(f"Most Popular Neighbourhood: {most_popular_neighbourhood['neighbourhood_cleansed']}")
print(f"Number of Listings: {most_popular_neighbourhood['number_of_listings']}")
print(f"Average Price: R${most_popular_neighbourhood['average_price']:.2f}")
print(f"Average Review Score: {most_popular_neighbourhood['average_review_score']:.0f}/100")
# Out:
# Most Popular Neighbourhood: Copacabana
# Number of Listings: 8530
# Average Price: R$498.17
# Average Review Score: 93/100

# %%
# Select the top 10 most popular neighbourhoods
top_10_neighbourhoods = neighbourhood_stats.head(10)

# Create a bar chart
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_neighbourhoods, x='neighbourhood_cleansed', y='number_of_listings', palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Listings')
plt.title('Top 10 Most Popular Neighbourhoods in Rio de Janeiro')
plt.show()

# %% [markdown]
# # Top 10 Most Expensive Neighbourhoods

# %%
# Sort by average price and select the Top 10 most expensive neighbourhoods
top_10_expensive_neighbourhoods = neighbourhood_stats.sort_values(by='average_price', ascending=False).head(10)

# Visualise the results
plt.figure(figsize=(14, 8))
sns.barplot(data=top_10_expensive_neighbourhoods, x='neighbourhood_cleansed', y='average_price', palette='coolwarm')
plt.xticks(rotation=90)
plt.xlabel('Neighbourhood')
plt.ylabel('Average Price')
plt.title('Top 10 Most Expensive Neighbourhoods')
plt.show()

# Analyse room types in these neighbourhoods
room_type_distribution = df[df['neighbourhood_cleansed'].isin(top_10_expensive_neighbourhoods['neighbourhood_cleansed'])].groupby(
    ['neighbourhood_cleansed', 'room_type']).size().unstack()

# Visualise room type distribution
room_type_distribution.plot(kind='bar', stacked=True, figsize=(14, 8))
plt.xlabel('Neighbourhood')
plt.ylabel('Number of Listings')
plt.title('Room Type Distribution in Top 10 Most Expensive Neighbourhoods')
plt.xticks(rotation=90)
plt.legend(title='Room Type')
plt.show()

# Sort by average price and select the Top 10 most expensive neighbourhoods
top_10_expensive_neighbourhoods = neighbourhood_stats.sort_values(by='average_price', ascending=False).head(10)

# Display the most expensive neighbourhood
most_expensive_neighbourhood = top_10_expensive_neighbourhoods.iloc[0]
print(f"Most Expensive Neighbourhood: {most_expensive_neighbourhood['neighbourhood_cleansed']}")
print(f"Average Price: R${most_expensive_neighbourhood['average_price']:.2f}")
# Out:
# Most Expensive Neighbourhood: Ramos
# Average Price: R$3472.33

# %% [markdown]
# # Top 20 Listings by Review Scores

# %%
# Sort by review scores and select the Top 20 listings
top_20_listings = df.sort_values(by='review_scores_rating', ascending=False).head(20)

# Analyse common features (e.g., amenities, host status, room type)
common_features = top_20_listings[['room_type', 'host_is_superhost', 'amenities']]

# Display the common features
print(common_features.describe())

# Visualise room type distribution in Top 20 listings
plt.figure(figsize=(10, 6))
sns.countplot(data=top_20_listings, x='room_type', palette='viridis')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Room Types in Top 20 Listings by Review Scores')
plt.show()
# Out:
#               room_type host_is_superhost  \
# count                20                20
# unique                3                 1
# top     Entire home/apt                 f
# freq                 13                20
#
#                                                 amenities
# count                                                  20
# unique                                                 20
# top     {"Smoking allowed","Pets allowed","Suitable fo...
# freq                                                    1

# %% [markdown]
# # Top 10 Room Types by Popularity

# %%
# Group by room type and calculate the number of listings
room_type_stats = df.groupby('room_type').agg(
    number_of_listings=('id', 'count'),
    average_price=('price', 'mean')
).reset_index()

# Sort by number of listings and select the Top 10
top_10_room_types = room_type_stats.sort_values(by='number_of_listings', ascending=False).head(1000)

# Visualise the results
plt.figure(figsize=(14, 8))
sns.barplot(data=top_10_room_types, x='room_type', y='number_of_listings', palette='coolwarm')
plt.xlabel('Room Type')
plt.ylabel('Number of Listings')
plt.title('Top 10 Most Popular Room Types')
plt.show()

# Analyse price and availability trends by month for Top 10 room types
df['month'] = pd.to_datetime(df['last_scraped']).dt.month
df['month'] = df['month'].astype(int) # Asegurar que 'month' es un entero
top_room_types_list = top_10_room_types['room_type'].tolist()
top_room_types_data = df[df['room_type'].isin(top_room_types_list)]

room_type_trends = top_room_types_data.groupby(['month', 'room_type']).agg(
    average_price=('price', 'mean'),
    average_availability=('availability_30', 'mean')
).reset_index()

# Visualise price trends
plt.figure(figsize=(14, 8))
sns.lineplot(data=room_type_trends, x='month', y='average_price', hue='room_type', style='room_type', markers=True, dashes=False)
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.title('Price Trends for Top 10 Room Types by Month')
plt.legend(title='Room Type')
plt.xticks(range(1, 13)) # Asegurar que los ticks del eje x son enteros
plt.show()

# Visualise availability trends
plt.figure(figsize=(14, 8))
sns.lineplot(data=room_type_trends, x='month', y='average_availability', hue='room_type', style='room_type', markers=True, dashes=False)
plt.xlabel('Month')
plt.ylabel('Average Availability (30 Days)')
plt.title('Availability Trends for Top 10 Room Types by Month')
plt.legend(title='Room Type')
plt.xticks(range(1, 13)) # Asegurar que los ticks del eje x son enteros
plt.show()

# %%
print(df['month'])
# Out:
# 0        9
# 1        9
# 2        9
# 3        9
# 4        9
#         ..
# 34324    9
# 34325    9
# 34326    9
# 34327    9
# 34328    9
# Name: month, Length: 34329, dtype: int32

# %% [markdown]
# Top 10 Hosts by Number of Listings

# %%
# Group by host and calculate the number of listings, average price, and average review score
host_stats = df.groupby('host_id').agg(
    host_name=('host_name', 'first'),
    number_of_listings=('id', 'count'),
    average_price=('price', 'mean'),
    average_review_score=('review_scores_rating', 'mean')
).reset_index()

# Sort by number of listings and select the Top 10 hosts
top_10_hosts = host_stats.sort_values(by='number_of_listings', ascending=False).head(10)

# Visualise the results
plt.figure(figsize=(14, 8))
sns.barplot(data=top_10_hosts, x='host_name', y='number_of_listings', color='blue', label='Number of Listings')
sns.lineplot(data=top_10_hosts, x='host_name', y='average_price', color='red', label='Average Price')
sns.lineplot(data=top_10_hosts, x='host_name', y='average_review_score', color='green', label='Average Review Score')
plt.xticks(rotation=90)
plt.xlabel('Host Name')
plt.ylabel('Value')
plt.title('Top 10 Hosts: Listings, Prices, and Review Scores')
plt.legend()
plt.show()
